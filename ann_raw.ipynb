# %% [markdown]
# # 人体动作识别 — ANN (基于原始信号)
#
# 使用 UCI HAR Dataset 的原始惯性信号 (128, 9)，展平后通过全连接网络识别 6 种日常动作。

# %% [markdown]
# ## 1. 导入依赖
#
# - `numpy` / `pandas`：数据处理
# - `tensorflow.keras`：构建 ANN 模型
# - `sklearn`：标准化

# %%
import glob, os
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import (
    Dense, Dropout, Flatten,
)
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

# %% [markdown]
# ## 2. 超参数配置
#
# - `N_CLASSES = 6`：6 种日常动作
# - `BATCH_SIZE = 64`：每批 64 条样本
# - `MAX_EPOCHS = 100`：最多训练 100 轮（早停会提前结束）

# %%
N_CLASSES   = 6

BATCH_SIZE  = 64
MAX_EPOCHS  = 100

# %% [markdown]
# ## 3. 数据加载
#
# UCI HAR 数据集中，每组（train/test）目录结构如下：
# - `Inertial Signals/` 下 9 个 `.txt` 文件，每个对应一种传感器通道
# - `y_train.txt` / `y_test.txt` 为标签（1~6）
#
# `np.stack` 将 9 个 `(样本数, 128)` 的通道文件沿最后一维堆叠为 `(样本数, 128, 9)`。

# %%
def load_dataset(data_dir):
    # 获取 Inertial Signals 目录下所有 txt 文件，排序保证通道顺序一致
    files = sorted(glob.glob(os.path.join(data_dir, 'Inertial Signals', '*.txt')))
    # 逐个读入 9 个传感器文件，沿最后一维堆叠为 (N, 128, 9)
    X = np.stack([np.loadtxt(f, dtype=np.float32) for f in files], axis=-1)
    # 从路径末尾提取 'train' 或 'test'
    group = os.path.basename(data_dir)
    # 读取标签文件 y_train.txt 或 y_test.txt
    y = np.loadtxt(os.path.join(data_dir, f'y_{group}.txt'), dtype=np.float32)
    print(f'{group}: X {X.shape}, y {y.shape}')
    return X, y

# %% [markdown]
# ## 4. 模型结构 — ANN
#
# 将原始信号 (128, 9) 展平为 1152 维向量，通过两层全连接网络分类：
#
# ```
# Flatten(128×9=1152)
#   → Dense(128, relu) → Dropout(0.5)
#   → Dense(64, relu) → Dropout(0.5)
#   → Softmax(6)
# ```

# %%
def build_model(input_shape):
    inputs = Input(shape=input_shape)
    x = Flatten()(inputs)
    x = Dense(128, activation='relu', kernel_regularizer=l2(1e-4))(x)
    x = Dropout(0.5)(x)
    x = Dense(64, activation='relu', kernel_regularizer=l2(1e-4))(x)
    x = Dropout(0.5)(x)
    outputs = Dense(N_CLASSES, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(loss='categorical_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(1e-3),
                  metrics=['accuracy'])
    return model

# %% [markdown]
# ## 5. 训练与评估
#
# 用全部训练集训练，留出 20% 做验证，早停后评估测试集。

# %%
X_train, y_train = load_dataset('./UCI HAR Dataset/train')
X_test,  y_test  = load_dataset('./UCI HAR Dataset/test')

# 标准化
scaler = StandardScaler().fit(X_train.reshape(-1, X_train.shape[-1]))
X_train = scaler.transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
X_test  = scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)

# one-hot 编码
y_train_ohe = to_categorical(y_train - 1)
y_test_ohe  = to_categorical(y_test - 1)

model = build_model(X_train.shape[1:])
model.fit(
    X_train, y_train_ohe,
    epochs=MAX_EPOCHS, batch_size=BATCH_SIZE, validation_split=0.2,
    callbacks=[
        EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6),
    ],
    verbose=1,
)

_, test_acc = model.evaluate(X_test, y_test_ohe, verbose=0)
print(f'测试集准确率: {test_acc * 100:.2f}%')
# Out:
# train: X (7352, 128, 9), y (7352,)
# test: X (2947, 128, 9), y (2947,)
# Epoch 1/100
# 92/92 [==============================] - 1s 4ms/step - loss: 1.4176 - accuracy: 0.5164 - val_loss: 0.6553 - val_accuracy: 0.8069 - lr: 0.0010
# Epoch 2/100
# 92/92 [==============================] - 0s 2ms/step - loss: 0.8774 - accuracy: 0.6871 - val_loss: 0.5078 - val_accuracy: 0.8878 - lr: 0.0010
# Epoch 3/100
# 92/92 [==============================] - 0s 2ms/step - loss: 0.6949 - accuracy: 0.7543 - val_loss: 0.4206 - val_accuracy: 0.9007 - lr: 0.0010
# Epoch 4/100
# 92/92 [==============================] - 0s 2ms/step - loss: 0.5965 - accuracy: 0.7907 - val_loss: 0.3937 - val_accuracy: 0.8987 - lr: 0.0010
# Epoch 5/100
# 92/92 [==============================] - 0s 2ms/step - loss: 0.5231 - accuracy: 0.8158 - val_loss: 0.3398 - val_accuracy: 0.9048 - lr: 0.0010
# Epoch 6/100
# 92/92 [==============================] - 0s 2ms/step - loss: 0.4583 - accuracy: 0.8442 - val_loss: 0.3276 - val_accuracy: 0.9096 - lr: 0.0010
# Epoch 7/100
# 92/92 [==============================] - 0s 2ms/step - loss: 0.4215 - accuracy: 0.8521 - val_loss: 0.3255 - val_accuracy: 0.9198 - lr: 0.0010
# Epoch 8/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.3702 - accuracy: 0.8733 - val_loss: 0.3122 - val_accuracy: 0.9239 - lr: 0.0010
# Epoch 9/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.3468 - accuracy: 0.8818 - val_loss: 0.3047 - val_accuracy: 0.9279 - lr: 0.0010
# Epoch 10/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.3442 - accuracy: 0.8851 - val_loss: 0.2740 - val_accuracy: 0.9300 - lr: 0.0010
# Epoch 11/100
# 92/92 [==============================] - 0s 4ms/step - loss: 0.3131 - accuracy: 0.8954 - val_loss: 0.3026 - val_accuracy: 0.9266 - lr: 0.0010
# Epoch 12/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.2929 - accuracy: 0.9032 - val_loss: 0.2867 - val_accuracy: 0.9279 - lr: 0.0010
# Epoch 13/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.2849 - accuracy: 0.9075 - val_loss: 0.3034 - val_accuracy: 0.9300 - lr: 0.0010
# Epoch 14/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.2918 - accuracy: 0.9019 - val_loss: 0.2789 - val_accuracy: 0.9307 - lr: 0.0010
# Epoch 15/100
# 92/92 [==============================] - 0s 2ms/step - loss: 0.2739 - accuracy: 0.9111 - val_loss: 0.2970 - val_accuracy: 0.9259 - lr: 0.0010
# Epoch 16/100
# 92/92 [==============================] - 0s 2ms/step - loss: 0.2711 - accuracy: 0.9109 - val_loss: 0.3011 - val_accuracy: 0.9334 - lr: 5.0000e-04
# Epoch 17/100
# 92/92 [==============================] - 0s 2ms/step - loss: 0.2272 - accuracy: 0.9289 - val_loss: 0.3061 - val_accuracy: 0.9307 - lr: 5.0000e-04
# Epoch 18/100
# 92/92 [==============================] - 0s 2ms/step - loss: 0.2364 - accuracy: 0.9237 - val_loss: 0.3120 - val_accuracy: 0.9293 - lr: 5.0000e-04
# Epoch 19/100
# 92/92 [==============================] - 0s 2ms/step - loss: 0.2261 - accuracy: 0.9255 - val_loss: 0.3032 - val_accuracy: 0.9286 - lr: 5.0000e-04
# Epoch 20/100
# 92/92 [==============================] - 0s 2ms/step - loss: 0.2279 - accuracy: 0.9221 - val_loss: 0.3159 - val_accuracy: 0.9259 - lr: 5.0000e-04
# Epoch 21/100
# 92/92 [==============================] - 0s 2ms/step - loss: 0.2189 - accuracy: 0.9294 - val_loss: 0.3047 - val_accuracy: 0.9286 - lr: 2.5000e-04
# Epoch 22/100
# 92/92 [==============================] - 0s 2ms/step - loss: 0.2087 - accuracy: 0.9350 - val_loss: 0.3128 - val_accuracy: 0.9286 - lr: 2.5000e-04
# Epoch 23/100
# 92/92 [==============================] - 0s 2ms/step - loss: 0.2125 - accuracy: 0.9364 - val_loss: 0.3167 - val_accuracy: 0.9293 - lr: 2.5000e-04
# Epoch 24/100
# 92/92 [==============================] - 0s 2ms/step - loss: 0.2083 - accuracy: 0.9352 - val_loss: 0.3026 - val_accuracy: 0.9286 - lr: 2.5000e-04
# Epoch 25/100
# 92/92 [==============================] - 0s 2ms/step - loss: 0.2034 - accuracy: 0.9378 - val_loss: 0.3051 - val_accuracy: 0.9300 - lr: 2.5000e-04
# 测试集准确率: 89.65%
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
