# %% [markdown]
# # 人体动作识别 — 多分支 1D-CNN
#
# 使用 UCI HAR Dataset，通过三个不同卷积核大小（3/5/7）的多头一维卷积神经网络识别 6 种日常动作。多分支设计可同时捕获不同时间尺度的运动模式。

# %% [markdown]
# ## 1. 导入依赖
#
# - `numpy` / `pandas`：数据处理
# - `tensorflow.keras`：构建 1D-CNN 模型
# - `sklearn`：标准化

# %%
import glob, os
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import (
    Conv1D, Dense, Dropout, MaxPooling1D,
    BatchNormalization, GlobalAveragePooling1D, concatenate
)
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

# %% [markdown]
# ## 2. 超参数配置
#
# - `N_CLASSES = 6`：6 种日常动作
# - `BATCH_SIZE = 64`：每批 64 条样本
# - `MAX_EPOCHS = 100`：最多训练 100 轮（早停会提前结束）

# %%
N_CLASSES   = 6

BATCH_SIZE  = 64
MAX_EPOCHS  = 100

# %% [markdown]
# ## 3. 数据加载
#
# UCI HAR 数据集中，每组（train/test）目录结构如下：
# - `Inertial Signals/` 下 9 个 `.txt` 文件，每个对应一种传感器通道
# - `y_train.txt` / `y_test.txt` 为标签（1~6）
#
# `np.stack` 将 9 个 `(样本数, 128)` 的通道文件沿最后一维堆叠为 `(样本数, 128, 9)`。

# %%
def load_dataset(data_dir):
    # 获取 Inertial Signals 目录下所有 txt 文件，排序保证通道顺序一致
    files = sorted(glob.glob(os.path.join(data_dir, 'Inertial Signals', '*.txt')))
    # 逐个读入 9 个传感器文件，沿最后一维堆叠为 (N, 128, 9)
    X = np.stack([np.loadtxt(f, dtype=np.float32) for f in files], axis=-1)
    # 从路径末尾提取 'train' 或 'test'
    group = os.path.basename(data_dir)
    # 读取标签文件 y_train.txt 或 y_test.txt
    y = np.loadtxt(os.path.join(data_dir, f'y_{group}.txt'), dtype=np.float32)
    print(f'{group}: X {X.shape}, y {y.shape}')
    return X, y

# %% [markdown]
# ## 4. 模型结构 — 多分支 1D-CNN
#
# 三个并行的卷积分支，卷积核大小分别为 **3、5、7**，从不同时间窗口提取特征：
#
# ```
# 输入 (128, 9)
#   ├─ Conv1D(64, 3) → Conv1D(64, 3) → MaxPool → Conv1D(128, 3) → MaxPool → GAP
#   ├─ Conv1D(64, 5) → Conv1D(64, 5) → MaxPool → Conv1D(128, 5) → MaxPool → GAP
#   └─ Conv1D(64, 7) → Conv1D(64, 7) → MaxPool → Conv1D(128, 7) → MaxPool → GAP
#        ↓
#   Concat → Dense(128) → Dropout(0.5) → Dense(64) → Dropout(0.5) → Softmax(6)
# ```
#
# 每层卷积后接 `BatchNormalization` 加速收敛，`l2(1e-4)` 正则化防过拟合。

# %%
def build_model(input_shape):
    inputs = Input(shape=input_shape)
    branches = []
    for k in [3, 5, 7]:
        x = Conv1D(64, k, activation='relu', padding='same',
                   kernel_regularizer=l2(1e-4))(inputs)
        x = BatchNormalization()(x)
        x = Conv1D(64, k, activation='relu', padding='same',
                   kernel_regularizer=l2(1e-4))(x)
        x = BatchNormalization()(x)
        x = MaxPooling1D(2)(x)
        x = Dropout(0.3)(x)
        x = Conv1D(128, k, activation='relu', padding='same',
                   kernel_regularizer=l2(1e-4))(x)
        x = BatchNormalization()(x)
        x = MaxPooling1D(2)(x)
        x = Dropout(0.3)(x)
        x = GlobalAveragePooling1D()(x)
        branches.append(x)

    x = concatenate(branches)
    x = Dense(128, activation='relu', kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(64, activation='relu', kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    outputs = Dense(N_CLASSES, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(loss='categorical_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(1e-3),
                  metrics=['accuracy'])
    return model

# %% [markdown]
# ## 5. 训练与评估
#
# 用全部训练集训练，留出 20% 做验证，早停后评估测试集。

# %%
X_train, y_train = load_dataset('./UCI HAR Dataset/train')
X_test,  y_test  = load_dataset('./UCI HAR Dataset/test')

# 标准化
scaler = StandardScaler().fit(X_train.reshape(-1, X_train.shape[-1]))
X_train = scaler.transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
X_test  = scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)

# one-hot 编码
y_train_ohe = to_categorical(y_train - 1)
y_test_ohe  = to_categorical(y_test - 1)

model = build_model(X_train.shape[1:])
model.fit(
    X_train, y_train_ohe,
    epochs=MAX_EPOCHS, batch_size=BATCH_SIZE, validation_split=0.2,
    callbacks=[
        EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6),
    ],
    verbose=1,
)

_, test_acc = model.evaluate(X_test, y_test_ohe, verbose=0)
print(f'测试集准确率: {test_acc * 100:.2f}%')
# Out:
# train: X (7352, 128, 9), y (7352,)
# test: X (2947, 128, 9), y (2947,)
# Epoch 1/100
# 92/92 [==============================] - 5s 18ms/step - loss: 0.5782 - accuracy: 0.8318 - val_loss: 0.5285 - val_accuracy: 0.9137 - lr: 0.0010
# Epoch 2/100
# 92/92 [==============================] - 1s 14ms/step - loss: 0.2707 - accuracy: 0.9388 - val_loss: 0.3316 - val_accuracy: 0.9286 - lr: 0.0010
# Epoch 3/100
# 92/92 [==============================] - 1s 14ms/step - loss: 0.2344 - accuracy: 0.9441 - val_loss: 0.2963 - val_accuracy: 0.9368 - lr: 0.0010
# Epoch 4/100
# 92/92 [==============================] - 1s 13ms/step - loss: 0.2200 - accuracy: 0.9449 - val_loss: 0.3250 - val_accuracy: 0.9395 - lr: 0.0010
# Epoch 5/100
# 92/92 [==============================] - 1s 13ms/step - loss: 0.2025 - accuracy: 0.9505 - val_loss: 0.3273 - val_accuracy: 0.9245 - lr: 0.0010
# Epoch 6/100
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1935 - accuracy: 0.9546 - val_loss: 0.3021 - val_accuracy: 0.9307 - lr: 0.0010
# Epoch 7/100
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1916 - accuracy: 0.9541 - val_loss: 0.3638 - val_accuracy: 0.9361 - lr: 0.0010
# Epoch 8/100
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1814 - accuracy: 0.9539 - val_loss: 0.3271 - val_accuracy: 0.9171 - lr: 0.0010
# Epoch 9/100
# 92/92 [==============================] - 1s 14ms/step - loss: 0.1746 - accuracy: 0.9558 - val_loss: 0.2970 - val_accuracy: 0.9361 - lr: 5.0000e-04
# Epoch 10/100
# 92/92 [==============================] - 1s 14ms/step - loss: 0.1649 - accuracy: 0.9587 - val_loss: 0.3082 - val_accuracy: 0.9395 - lr: 5.0000e-04
# Epoch 11/100
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1612 - accuracy: 0.9607 - val_loss: 0.3095 - val_accuracy: 0.9218 - lr: 5.0000e-04
# Epoch 12/100
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1576 - accuracy: 0.9592 - val_loss: 0.2811 - val_accuracy: 0.9225 - lr: 5.0000e-04
# Epoch 13/100
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1583 - accuracy: 0.9617 - val_loss: 0.4016 - val_accuracy: 0.9415 - lr: 5.0000e-04
# Epoch 14/100
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1568 - accuracy: 0.9612 - val_loss: 0.2624 - val_accuracy: 0.9048 - lr: 5.0000e-04
# Epoch 15/100
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1512 - accuracy: 0.9640 - val_loss: 0.3325 - val_accuracy: 0.9409 - lr: 5.0000e-04
# Epoch 16/100
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1506 - accuracy: 0.9624 - val_loss: 0.2988 - val_accuracy: 0.9300 - lr: 5.0000e-04
# Epoch 17/100
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1445 - accuracy: 0.9636 - val_loss: 0.2809 - val_accuracy: 0.9239 - lr: 5.0000e-04
# Epoch 18/100
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1510 - accuracy: 0.9638 - val_loss: 0.3312 - val_accuracy: 0.9381 - lr: 5.0000e-04
# Epoch 19/100
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1499 - accuracy: 0.9612 - val_loss: 0.2788 - val_accuracy: 0.9279 - lr: 5.0000e-04
# Epoch 20/100
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1435 - accuracy: 0.9648 - val_loss: 0.2969 - val_accuracy: 0.9368 - lr: 2.5000e-04
# Epoch 21/100
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1429 - accuracy: 0.9667 - val_loss: 0.3173 - val_accuracy: 0.9368 - lr: 2.5000e-04
# Epoch 22/100
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1373 - accuracy: 0.9672 - val_loss: 0.3168 - val_accuracy: 0.9388 - lr: 2.5000e-04
# Epoch 23/100
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1352 - accuracy: 0.9662 - val_loss: 0.3023 - val_accuracy: 0.9511 - lr: 2.5000e-04
# Epoch 24/100
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1324 - accuracy: 0.9679 - val_loss: 0.2927 - val_accuracy: 0.9211 - lr: 2.5000e-04
# Epoch 25/100
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1309 - accuracy: 0.9682 - val_loss: 0.2831 - val_accuracy: 0.9211 - lr: 1.2500e-04
# Epoch 26/100
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1318 - accuracy: 0.9691 - val_loss: 0.2863 - val_accuracy: 0.9116 - lr: 1.2500e-04
# Epoch 27/100
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1239 - accuracy: 0.9731 - val_loss: 0.3076 - val_accuracy: 0.9341 - lr: 1.2500e-04
# Epoch 28/100
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1241 - accuracy: 0.9735 - val_loss: 0.3392 - val_accuracy: 0.9286 - lr: 1.2500e-04
# Epoch 29/100
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1230 - accuracy: 0.9733 - val_loss: 0.3228 - val_accuracy: 0.9402 - lr: 1.2500e-04
# 测试集准确率: 91.14%
